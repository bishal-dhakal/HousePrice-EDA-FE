# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

##Display all the columns of the dataset
pd.pandas.set_option('display.max_columns',None)

# %%
dataset=pd.read_csv('train.csv')
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
# 2       Norm     1Fam     2Story            7            5       2001
# 3       Norm     1Fam     2Story            7            5       1915
# 4       Norm     1Fam     2Story            8            5       2000
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
# 2          2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3          1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4          2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# 0       196.0        Gd        TA      PConc       Gd       TA           No
# 1         0.0        TA        TA     CBlock       Gd       TA           Gd
# 2       162.0        Gd        TA      PConc       Gd       TA           Mn
# 3         0.0        TA        TA     BrkTil       TA       Gd           No
# 4       350.0        Gd        TA      PConc       Gd       TA           Av
#
#   BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# 0          GLQ         706          Unf           0        150          856
# 1          ALQ         978          Unf           0        284         1262
# 2          GLQ         486          Unf           0        434          920
# 3          ALQ         216          Unf           0        540          756
# 4          GLQ         655          Unf           0        490         1145
#
#   Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# 0    GasA        Ex          Y      SBrkr       856       854             0
# 1    GasA        Ex          Y      SBrkr      1262         0             0
# 2    GasA        Ex          Y      SBrkr       920       866             0
# 3    GasA        Gd          Y      SBrkr       961       756             0
# 4    GasA        Ex          Y      SBrkr      1145      1053             0
#
#    GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# 0       1710             1             0         2         1             3
# 1       1262             0             1         2         0             3
# 2       1786             1             0         2         1             3
# 3       1717             1             0         1         0             3
# 4       2198             1             0         2         1             4
#
#    KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# 0             1          Gd             8        Typ           0         NaN
# 1             1          TA             6        Typ           1          TA
# 2             1          Gd             6        Typ           1          TA
# 3             1          Gd             7        Typ           1          Gd
# 4             1          Gd             9        Typ           1          TA
#
#   GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# 0     Attchd       2003.0          RFn           2         548         TA
# 1     Attchd       1976.0          RFn           2         460         TA
# 2     Attchd       2001.0          RFn           2         608         TA
# 3     Detchd       1998.0          Unf           3         642         TA
# 4     Attchd       2000.0          RFn           3         836         TA
#
#   GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# 0         TA          Y           0           61              0          0
# 1         TA          Y         298            0              0          0
# 2         TA          Y           0           42              0          0
# 3         TA          Y           0           35            272          0
# 4         TA          Y         192           84              0          0
#
#    ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0         0    NaN   NaN         NaN        0       2    2008
# 1            0         0    NaN   NaN         NaN        0       5    2007
# 2            0         0    NaN   NaN         NaN        0       9    2008
# 3            0         0    NaN   NaN         NaN        0       2    2006
# 4            0         0    NaN   NaN         NaN        0      12    2008
#
#   SaleType SaleCondition  SalePrice
# 0       WD        Normal     208500
# 1       WD        Normal     181500
# 2       WD        Normal     223500
# 3       WD       Abnorml     140000
# 4       WD        Normal     250000

# %%
X=dataset.iloc[:,1:81]
y=dataset.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 450           30       RM         70.0     5684   Pave   NaN      Reg
# 670           60       RL         64.0     8633   Pave   NaN      Reg
# 609           20       RL         61.0     7943   Pave   NaN      Reg
# 42            85       RL          NaN     9180   Pave   NaN      IR1
# 1449         180       RM         21.0     1533   Pave   NaN      Reg
# ...          ...      ...          ...      ...    ...   ...      ...
# 492           60       RL        105.0    15578   Pave   NaN      IR1
# 642           80       RL         75.0    13860   Pave   NaN      Reg
# 488          190       RL         60.0    10800   Pave   NaN      Reg
# 211           20       RL         83.0    10420   Pave   NaN      Reg
# 458           70       RM          NaN     5100   Pave  Grvl      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 450          Lvl    AllPub    Inside       Gtl      OldTown       Norm
# 670          Lvl    AllPub       FR2       Gtl      CollgCr       Norm
# 609          Lvl    AllPub    Inside       Gtl       Sawyer      Feedr
# 42           Lvl    AllPub   CulDSac       Gtl      SawyerW       Norm
# 1449         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# ...          ...       ...       ...       ...          ...        ...
# 492          Lvl    AllPub    Corner       Gtl      Gilbert       Norm
# 642          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 488          Lvl    AllPub    Corner       Gtl      OldTown       Norm
# 211          Lvl    AllPub    Corner       Gtl      Edwards       Norm
# 458          Lvl    AllPub    Inside       Gtl      OldTown       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 450        Norm     1Fam     1Story            6            8       1930
# 670        Norm     1Fam     2Story            6            5       2005
# 609        Norm     1Fam     1Story            4            5       1961
# 42         Norm     1Fam     SFoyer            5            7       1983
# 1449       Norm    Twnhs     SFoyer            5            7       1970
# ...         ...      ...        ...          ...          ...        ...
# 492        Norm     1Fam     2Story            6            5       2006
# 642        Norm     1Fam       SLvl            8            7       1972
# 488        Norm   2fmCon     1.5Fin            5            4       1900
# 211        Norm     1Fam     1Story            6            5       2009
# 458        Norm     1Fam     2Story            8            7       1925
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 450           2005       Hip  CompShg     Wd Sdng     Wd Sdng       None
# 670           2005     Gable  CompShg     VinylSd     VinylSd       None
# 609           1961     Gable  CompShg     VinylSd     VinylSd     BrkCmn
# 42            1983     Gable  CompShg     HdBoard     HdBoard       None
# 1449          1970     Gable  CompShg     CemntBd     CmentBd       None
# ...            ...       ...      ...         ...         ...        ...
# 492           2006     Gable  CompShg     VinylSd     VinylSd       None
# 642           1995     Gable  CompShg     Plywood     Wd Sdng       None
# 488           1970     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 211           2009     Gable  CompShg     VinylSd     VinylSd       None
# 458           1996       Hip  CompShg      Stucco     Wd Shng       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 450          0.0        TA        TA     BrkTil       TA       TA
# 670          0.0        Gd        TA      PConc       Gd       TA
# 609        192.0        TA        Fa     CBlock       TA       TA
# 42           0.0        TA        TA     CBlock       Gd       TA
# 1449         0.0        TA        TA     CBlock       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 492          0.0        Gd        TA      PConc       Gd       TA
# 642          0.0        Gd        TA     CBlock       Gd       TA
# 488          0.0        TA        Fa     CBlock       TA       Fa
# 211          0.0        TA        TA      PConc       Gd       TA
# 458          0.0        TA        Gd      PConc       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 450            No          Unf           0          Unf           0
# 670            No          GLQ         193          Unf           0
# 609            Mn          Rec         903          Unf           0
# 42             Av          ALQ         747          LwQ          93
# 1449           Av          GLQ         553          Unf           0
# ...           ...          ...         ...          ...         ...
# 492            No          Unf           0          Unf           0
# 642            Gd          GLQ        1410          Unf           0
# 488            No          BLQ         664          Unf           0
# 211            Mn          GLQ          36          Unf           0
# 458            No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 450         813          813    GasA        Ex          Y      FuseA
# 670         545          738    GasA        Ex          Y      SBrkr
# 609         126         1029    GasA        Gd          Y      SBrkr
# 42            0          840    GasA        Gd          Y      SBrkr
# 1449         77          630    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 492         728          728    GasA        Gd          Y      SBrkr
# 642         542         1952    GasA        Gd          Y      SBrkr
# 488         290          954    GasA        TA          N      FuseA
# 211        1176         1212    GasA        Ex          Y      SBrkr
# 458         588          588    GasA        Fa          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 450        813         0             0        813             0             0
# 670        738       738             0       1476             1             0
# 609       1029         0             0       1029             1             0
# 42         884         0             0        884             1             0
# 1449       630         0             0        630             1             0
# ...        ...       ...           ...        ...           ...           ...
# 492        728       728             0       1456             0             0
# 642       2000       704             0       2704             1             0
# 488       1766       648             0       2414             0             0
# 211       1212         0             0       1212             0             0
# 458        833       833             0       1666             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 450          1         0             2             1          Gd
# 670          2         1             3             1          Gd
# 609          1         0             3             1          TA
# 42           1         0             2             1          Gd
# 1449         1         0             1             1          Ex
# ...        ...       ...           ...           ...         ...
# 492          2         1             3             1          TA
# 642          2         1             4             1          Ex
# 488          2         0             3             2          TA
# 211          2         0             3             1          Gd
# 458          1         0             3             1          Gd
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 450              5        Typ           0         NaN     Detchd       1932.0
# 670              7        Typ           0         NaN     Attchd       2005.0
# 609              5        Typ           0         NaN     Attchd       1961.0
# 42               5        Typ           0         NaN     Attchd       1983.0
# 1449             3        Typ           0         NaN        NaN          NaN
# ...            ...        ...         ...         ...        ...          ...
# 492              8        Typ           0         NaN     Attchd       2006.0
# 642              9        Typ           3          TA     Attchd       1972.0
# 488             10        Mod           1          Gd     Attchd       1970.0
# 211              6        Typ           0         NaN     Attchd       2009.0
# 458              7        Typ           1          Gd     Detchd       1925.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 450           Unf           1         270         Fa         Fa          N
# 670           Fin           2         540         TA         TA          Y
# 609           Unf           1         261         TA         TA          Y
# 42            RFn           2         504         TA         Gd          Y
# 1449          NaN           0           0        NaN        NaN          Y
# ...           ...         ...         ...        ...        ...        ...
# 492           RFn           2         429         TA         TA          Y
# 642           Fin           2         538         TA         TA          Y
# 488           Unf           2         520         TA         Fa          N
# 211           RFn           2         460         TA         TA          Y
# 458           Unf           1         228         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 450            0          113              0          0            0
# 670          100           35              0          0            0
# 609           64            0             39          0            0
# 42           240            0              0          0            0
# 1449           0            0              0          0            0
# ...          ...          ...            ...        ...          ...
# 492            0            0              0          0            0
# 642          269          111              0          0            0
# 488          142            0              0          0            0
# 211          100           22              0          0            0
# 458          192           63              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 450          0    NaN    NaN         NaN        0       6    2006       WD
# 670          0    NaN    NaN         NaN        0       2    2009       WD
# 609          0    NaN    NaN         NaN        0       4    2007       WD
# 42           0    NaN  MnPrv         NaN        0      12    2007       WD
# 1449         0    NaN    NaN         NaN        0       8    2006       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 492          0    NaN    NaN         NaN        0       5    2006      New
# 642          0    NaN  MnPrv         NaN        0       7    2009       WD
# 488          0    NaN    NaN         NaN        0       5    2006    ConLD
# 211          0    NaN    NaN         NaN        0       3    2010       WD
# 458          0    NaN  MnPrv         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice
# 450         Normal     110000
# 670         Normal     173500
# 609         Normal     118500
# 42          Normal     144000
# 1449       Abnorml      92000
# ...            ...        ...
# 492        Partial     172785
# 642         Normal     345000
# 488         Normal     160000
# 211         Normal     186000
# 458         Normal     161000
#
# [1314 rows x 80 columns]

# %%
X_test
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1164          80       RL          NaN    16157   Pave   NaN      IR1
# 400          120       RL         38.0    14963   Pave   NaN      IR2
# 731           80       RL         73.0     9590   Pave   NaN      IR1
# 1034          30       RL         50.0     6305   Pave   NaN      Reg
# 672           20       RL          NaN    11250   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 410           20       RL         68.0     9571   Pave   NaN      Reg
# 656           20       RL         72.0    10007   Pave   NaN      IR1
# 526           20       RL         70.0    13300   Pave   NaN      Reg
# 653           50       RM         60.0    10320   Pave  Grvl      Reg
# 778           90       RH         60.0     8400   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1164         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 400          Lvl    AllPub    Inside       Gtl      Veenker       Norm
# 731          Lvl    AllPub    Corner       Gtl       Timber       Norm
# 1034         Bnk    AllPub    Inside       Gtl      Crawfor       Norm
# 672          Lvl    AllPub    Inside       Gtl      Veenker       Norm
# ...          ...       ...       ...       ...          ...        ...
# 410          Lvl    AllPub    Inside       Gtl      Edwards       Norm
# 656          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 526          Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 653          Lvl    AllPub    Inside       Gtl       IDOTRR       Norm
# 778          Lvl    AllPub    Inside       Gtl      SawyerW      Feedr
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 1164       Norm     1Fam       SLvl            5            7       1978
# 400        Norm   TwnhsE     1Story            8            5       1996
# 731        Norm     1Fam       SLvl            7            5       2003
# 1034       Norm     1Fam     1Story            5            7       1938
# 672        Norm     1Fam     1Story            6            6       1977
# ...         ...      ...        ...          ...          ...        ...
# 410        Norm     1Fam     1Story            5            3       1958
# 656        Norm     1Fam     1Story            5            7       1959
# 526        Norm     1Fam     1Story            5            7       1956
# 653        Norm     1Fam     1.5Fin            6            7       1906
# 778        Norm   Duplex     1Story            5            5       1977
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 1164          1978     Gable  CompShg     Plywood     Plywood       None
# 400           1996     Gable  CompShg     BrkFace     BrkFace       None
# 731           2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1034          1950     Gable  CompShg     MetalSd     MetalSd       None
# 672           1977     Gable  CompShg     Plywood     Plywood       None
# ...            ...       ...      ...         ...         ...        ...
# 410           1958     Gable  CompShg     BrkComm     Brk Cmn       None
# 656           2006     Gable  CompShg     HdBoard     HdBoard    BrkFace
# 526           2000       Hip  CompShg     Wd Sdng     Wd Sdng       None
# 653           1995     Gable  CompShg     MetalSd     MetalSd       None
# 778           1977     Gable  CompShg     Plywood     Plywood    BrkFace
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 1164         0.0        TA        TA      PConc       Gd       TA
# 400          0.0        Gd        TA      PConc       Gd       TA
# 731        442.0        Gd        TA      PConc       Ex       TA
# 1034         0.0        TA        Gd      PConc       Fa       Fa
# 672          0.0        Gd        TA     CBlock       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 410          0.0        TA        Fa     CBlock       TA       Fa
# 656         54.0        Gd        TA     CBlock       TA       TA
# 526          0.0        TA        TA     CBlock       Gd       TA
# 653          0.0        TA        TA     CBlock       TA       TA
# 778        320.0        TA        TA       Slab      NaN      NaN
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 1164           Gd          ALQ         680          Rec         391
# 400            No          GLQ         786          Unf           0
# 731            Av          GLQ         786          Unf           0
# 1034           No          Unf           0          Unf           0
# 672            No          ALQ         767          Unf           0
# ...           ...          ...         ...          ...         ...
# 410            No          Unf           0          Unf           0
# 656            No          ALQ         806          Unf           0
# 526            No          Rec         377          Unf           0
# 653            No          Unf           0          Unf           0
# 778           NaN          NaN           0          NaN           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 1164        289         1360    GasA        Ex          Y      SBrkr
# 400         474         1260    GasA        Ex          Y      SBrkr
# 731          82          868    GasA        Ex          Y      SBrkr
# 1034        920          920    GasA        Ex          Y      SBrkr
# 672         441         1208    GasA        TA          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 410        1276         1276    GasA        TA          Y      FuseA
# 656         247         1053    GasA        Ex          Y      SBrkr
# 526         551          928    GasA        TA          Y      SBrkr
# 653         756          756    GasA        Ex          Y      SBrkr
# 778           0            0    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 1164      1432         0             0       1432             1             0
# 400       1288         0             0       1288             1             0
# 731       1146         0             0       1146             1             0
# 1034       954         0             0        954             0             0
# 672       1208         0             0       1208             1             0
# ...        ...       ...           ...        ...           ...           ...
# 410       1276         0             0       1276             0             0
# 656       1053         0             0       1053             1             0
# 526        928         0             0        928             0             0
# 653        756       713             0       1469             0             0
# 778       2020         0             0       2020             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 1164         1         1             2             1          Gd
# 400          1         1             1             1          Ex
# 731          2         0             3             1          Gd
# 1034         1         0             2             1          Fa
# 672          1         1             3             1          TA
# ...        ...       ...           ...           ...         ...
# 410          1         0             3             1          TA
# 656          1         1             3             1          Gd
# 526          1         0             2             1          TA
# 653          1         0             3             1          TA
# 778          2         0             4             2          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 1164             5        Typ           1          TA     Attchd       1978.0
# 400              4        Typ           2          Gd     Attchd       1996.0
# 731              6        Typ           1          Gd     Attchd       2003.0
# 1034             5        Typ           1          Gd    Basment       1938.0
# 672              6        Typ           1          TA     Attchd       1977.0
# ...            ...        ...         ...         ...        ...          ...
# 410              5        Mod           0         NaN     Attchd       1958.0
# 656              5        Typ           0         NaN     Attchd       1959.0
# 526              4        Typ           0         NaN     Attchd       1956.0
# 653              7        Typ           0         NaN     Detchd       1906.0
# 778             10        Typ           2          TA     Detchd       1977.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 1164          Unf           2         588         TA         TA          Y
# 400           Fin           2         500         TA         TA          Y
# 731           Fin           2         438         TA         TA          Y
# 1034          Unf           1         240         Fa         TA          Y
# 672           RFn           2         546         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 410           Unf           1         350         TA         TA          Y
# 656           RFn           1         312         TA         TA          Y
# 526           Unf           1         252         TA         TA          Y
# 653           Unf           1         216         TA         TA          Y
# 778           Unf           2         630         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 1164         168          180              0          0            0
# 400          120           30              0          0          224
# 731          160           22              0          0            0
# 1034           0            0              0          0            0
# 672          198           42              0          0            0
# ...          ...          ...            ...        ...          ...
# 410            0            0              0          0            0
# 656            0            0              0          0            0
# 526          261            0            156          0            0
# 653           57            0            239          0            0
# 778            0            0              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 1164         0    NaN    NaN         NaN        0       6    2007       WD
# 400          0    NaN    NaN         NaN        0      12    2008       WD
# 731          0    NaN    NaN         NaN        0       5    2007       WD
# 1034         0    NaN  MnPrv         NaN        0       6    2007       WD
# 672          0    NaN    NaN         NaN        0       6    2006       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 410          0    NaN    NaN         NaN        0       6    2009      COD
# 656          0    NaN  MnPrv         NaN        0       8    2008       WD
# 526          0    NaN    NaN         NaN        0       6    2007       WD
# 653          0    NaN  MnPrv         NaN        0       6    2008       WD
# 778          0    NaN    NaN         NaN        0      10    2007       WD
#
#      SaleCondition  SalePrice
# 1164        Normal     194000
# 400         Normal     245500
# 731         Normal     187500
# 1034        Normal     119750
# 672         Normal     165000
# ...            ...        ...
# 410        Abnorml      60000
# 656         Normal     145500
# 526         Normal     132000
# 653         Normal     135000
# 778         Normal     144000
#
# [146 rows x 80 columns]

# %%
y_train
# Out:
# 450     110000
# 670     173500
# 609     118500
# 42      144000
# 1449     92000
#          ...
# 492     172785
# 642     345000
# 488     160000
# 211     186000
# 458     161000
# Name: SalePrice, Length: 1314, dtype: int64

# %%
#missing Values
feature_nan=[feature for feature in dataset.columns if dataset[feature].isnull().sum()>=1]
for feature in feature_nan:
    print("The feature is {} and missing values in {}%".format(feature,np.round(dataset[feature].isnull().mean()*100,4)))
# Out:
# The feature is LotFrontage and missing values in 17.7397%
# The feature is Alley and missing values in 93.7671%
# The feature is MasVnrType and missing values in 0.5479%
# The feature is MasVnrArea and missing values in 0.5479%
# The feature is BsmtQual and missing values in 2.5342%
# The feature is BsmtCond and missing values in 2.5342%
# The feature is BsmtExposure and missing values in 2.6027%
# The feature is BsmtFinType1 and missing values in 2.5342%
# The feature is BsmtFinType2 and missing values in 2.6027%
# The feature is Electrical and missing values in 0.0685%
# The feature is FireplaceQu and missing values in 47.2603%
# The feature is GarageType and missing values in 5.5479%
# The feature is GarageYrBlt and missing values in 5.5479%
# The feature is GarageFinish and missing values in 5.5479%
# The feature is GarageQual and missing values in 5.5479%
# The feature is GarageCond and missing values in 5.5479%
# The feature is PoolQC and missing values in 99.5205%
# The feature is Fence and missing values in 80.7534%
# The feature is MiscFeature and missing values in 96.3014%

# %%
#replacing categorical features
categorical_features=[feature for feature in dataset.columns if dataset[feature].dtypes=='O']

# %%
categorical_features
# Out:
# ['MSZoning',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  'KitchenQual',
#  'Functional',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PavedDrive',
#  'PoolQC',
#  'Fence',
#  'MiscFeature',
#  'SaleType',
#  'SaleCondition']

# %%
#replacing categorical data with 'missing' 
data=dataset.copy()
def replace_cat_features(dataset,categorical_features):
    data[categorical_features]=data[categorical_features].fillna('Missing')
    return data

# %%
replace_cat_features(data,categorical_features)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street    Alley  \
# 0        1          60       RL         65.0     8450   Pave  Missing
# 1        2          20       RL         80.0     9600   Pave  Missing
# 2        3          60       RL         68.0    11250   Pave  Missing
# 3        4          70       RL         60.0     9550   Pave  Missing
# 4        5          60       RL         84.0    14260   Pave  Missing
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  Missing
# 1456  1457          20       RL         85.0    13175   Pave  Missing
# 1457  1458          70       RL         66.0     9042   Pave  Missing
# 1458  1459          20       RL         68.0     9717   Pave  Missing
# 1459  1460          20       RL         75.0     9937   Pave  Missing
#
#      LotShape LandContour Utilities LotConfig LandSlope Neighborhood  \
# 0         Reg         Lvl    AllPub    Inside       Gtl      CollgCr
# 1         Reg         Lvl    AllPub       FR2       Gtl      Veenker
# 2         IR1         Lvl    AllPub    Inside       Gtl      CollgCr
# 3         IR1         Lvl    AllPub    Corner       Gtl      Crawfor
# 4         IR1         Lvl    AllPub       FR2       Gtl      NoRidge
# ...       ...         ...       ...       ...       ...          ...
# 1455      Reg         Lvl    AllPub    Inside       Gtl      Gilbert
# 1456      Reg         Lvl    AllPub    Inside       Gtl       NWAmes
# 1457      Reg         Lvl    AllPub    Inside       Gtl      Crawfor
# 1458      Reg         Lvl    AllPub    Inside       Gtl        NAmes
# 1459      Reg         Lvl    AllPub    Inside       Gtl      Edwards
#
#      Condition1 Condition2 BldgType HouseStyle  OverallQual  OverallCond  \
# 0          Norm       Norm     1Fam     2Story            7            5
# 1         Feedr       Norm     1Fam     1Story            6            8
# 2          Norm       Norm     1Fam     2Story            7            5
# 3          Norm       Norm     1Fam     2Story            7            5
# 4          Norm       Norm     1Fam     2Story            8            5
# ...         ...        ...      ...        ...          ...          ...
# 1455       Norm       Norm     1Fam     2Story            6            5
# 1456       Norm       Norm     1Fam     1Story            6            6
# 1457       Norm       Norm     1Fam     2Story            7            9
# 1458       Norm       Norm     1Fam     1Story            5            6
# 1459       Norm       Norm     1Fam     1Story            5            6
#
#       YearBuilt  YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd  \
# 0          2003          2003     Gable  CompShg     VinylSd     VinylSd
# 1          1976          1976     Gable  CompShg     MetalSd     MetalSd
# 2          2001          2002     Gable  CompShg     VinylSd     VinylSd
# 3          1915          1970     Gable  CompShg     Wd Sdng     Wd Shng
# 4          2000          2000     Gable  CompShg     VinylSd     VinylSd
# ...         ...           ...       ...      ...         ...         ...
# 1455       1999          2000     Gable  CompShg     VinylSd     VinylSd
# 1456       1978          1988     Gable  CompShg     Plywood     Plywood
# 1457       1941          2006     Gable  CompShg     CemntBd     CmentBd
# 1458       1950          1996       Hip  CompShg     MetalSd     MetalSd
# 1459       1965          1965     Gable  CompShg     HdBoard     HdBoard
#
#      MasVnrType  MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0       BrkFace       196.0        Gd        TA      PConc       Gd       TA
# 1          None         0.0        TA        TA     CBlock       Gd       TA
# 2       BrkFace       162.0        Gd        TA      PConc       Gd       TA
# 3          None         0.0        TA        TA     BrkTil       TA       Gd
# 4       BrkFace       350.0        Gd        TA      PConc       Gd       TA
# ...         ...         ...       ...       ...        ...      ...      ...
# 1455       None         0.0        TA        TA      PConc       Gd       TA
# 1456      Stone       119.0        TA        TA     CBlock       Gd       TA
# 1457       None         0.0        Ex        Gd      Stone       TA       Gd
# 1458       None         0.0        TA        TA     CBlock       TA       TA
# 1459       None         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0     Missing     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0     Missing     Attchd       1950.0
# 1459             6        Typ           0     Missing     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea   PoolQC    Fence MiscFeature  MiscVal  MoSold  YrSold  \
# 0            0  Missing  Missing     Missing        0       2    2008
# 1            0  Missing  Missing     Missing        0       5    2007
# 2            0  Missing  Missing     Missing        0       9    2008
# 3            0  Missing  Missing     Missing        0       2    2006
# 4            0  Missing  Missing     Missing        0      12    2008
# ...        ...      ...      ...         ...      ...     ...     ...
# 1455         0  Missing  Missing     Missing        0       8    2007
# 1456         0  Missing    MnPrv     Missing        0       2    2010
# 1457         0  Missing    GdPrv        Shed     2500       5    2010
# 1458         0  Missing  Missing     Missing        0       4    2010
# 1459         0  Missing  Missing     Missing        0       6    2008
#
#      SaleType SaleCondition  SalePrice
# 0          WD        Normal     208500
# 1          WD        Normal     181500
# 2          WD        Normal     223500
# 3          WD       Abnorml     140000
# 4          WD        Normal     250000
# ...       ...           ...        ...
# 1455       WD        Normal     175000
# 1456       WD        Normal     210000
# 1457       WD        Normal     266500
# 1458       WD        Normal     142125
# 1459       WD        Normal     147500
#
# [1460 rows x 81 columns]

# %%
#replacing categorical data with 'mode'
data=dataset.copy()
def replace_cat_features(dataset,categorical_features):
    data[categorical_features]=data[categorical_features].fillna(data[categorical_features].mode())
    return data

# %%
replace_cat_features(data,categorical_features)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam     2Story            7            5       2003
# 1          Norm     1Fam     1Story            6            8       1976
# 2          Norm     1Fam     2Story            7            5       2001
# 3          Norm     1Fam     2Story            7            5       1915
# 4          Norm     1Fam     2Story            8            5       2000
# ...         ...      ...        ...          ...          ...        ...
# 1455       Norm     1Fam     2Story            6            5       1999
# 1456       Norm     1Fam     1Story            6            6       1978
# 1457       Norm     1Fam     2Story            7            9       1941
# 1458       Norm     1Fam     1Story            5            6       1950
# 1459       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd       None
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1455          2000     Gable  CompShg     VinylSd     VinylSd       None
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd       None
# 1458          1996       Hip  CompShg     MetalSd     MetalSd       None
# 1459          1965     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 4          350.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0          Gd     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0     Gd  MnPrv        Shed        0       2    2008       WD
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 2            0    NaN    NaN         NaN        0       9    2008       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1456         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice
# 0           Normal     208500
# 1           Normal     181500
# 2           Normal     223500
# 3          Abnorml     140000
# 4           Normal     250000
# ...            ...        ...
# 1455        Normal     175000
# 1456        Normal     210000
# 1457        Normal     266500
# 1458        Normal     142125
# 1459        Normal     147500
#
# [1460 rows x 81 columns]

# %%
numerical_features_nan=[feature for feature in dataset.columns if dataset[feature].dtypes !='O' and
                    dataset[feature].isnull().sum()>=1]

# %%
numerical_features_nan
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
for feature in numerical_features_nan:
    #since there are outliers we are going to replace with median
    median_values = dataset[feature].median()
    #create a new feature to capture nan value
    dataset[feature+'nan']= np.where(dataset[feature].isnull(),1,0)
    dataset[feature].fillna(median_values,inplace=True)

# %%
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam     2Story            7            5       2003
# 1          Norm     1Fam     1Story            6            8       1976
# 2          Norm     1Fam     2Story            7            5       2001
# 3          Norm     1Fam     2Story            7            5       1915
# 4          Norm     1Fam     2Story            8            5       2000
# ...         ...      ...        ...          ...          ...        ...
# 1455       Norm     1Fam     2Story            6            5       1999
# 1456       Norm     1Fam     1Story            6            6       1978
# 1457       Norm     1Fam     2Story            7            9       1941
# 1458       Norm     1Fam     1Story            5            6       1950
# 1459       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd       None
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1455          2000     Gable  CompShg     VinylSd     VinylSd       None
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd       None
# 1458          1996       Hip  CompShg     MetalSd     MetalSd       None
# 1459          1965     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 4          350.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN    NaN         NaN        0       2    2008       WD
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 2            0    NaN    NaN         NaN        0       9    2008       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1456         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# 0           Normal     208500               0              0               0
# 1           Normal     181500               0              0               0
# 2           Normal     223500               0              0               0
# 3          Abnorml     140000               0              0               0
# 4           Normal     250000               0              0               0
# ...            ...        ...             ...            ...             ...
# 1455        Normal     175000               0              0               0
# 1456        Normal     210000               0              0               0
# 1457        Normal     266500               0              0               0
# 1458        Normal     142125               0              0               0
# 1459        Normal     147500               0              0               0
#
# [1460 rows x 84 columns]

# %%
dataset['LotFrontage'].isnull().sum()
# Out:
# 0

# %%
#temporal varisables
for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
    dataset[feature+'age of house']= dataset['YrSold']-dataset[feature]

# %%
dataset
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1            Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2            Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3            Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4            Lvl    AllPub       FR2       Gtl      NoRidge       Norm
# ...          ...       ...       ...       ...          ...        ...
# 1455         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 1456         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Crawfor       Norm
# 1458         Lvl    AllPub    Inside       Gtl        NAmes       Norm
# 1459         Lvl    AllPub    Inside       Gtl      Edwards       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0          Norm     1Fam     2Story            7            5       2003
# 1          Norm     1Fam     1Story            6            8       1976
# 2          Norm     1Fam     2Story            7            5       2001
# 3          Norm     1Fam     2Story            7            5       1915
# 4          Norm     1Fam     2Story            8            5       2000
# ...         ...      ...        ...          ...          ...        ...
# 1455       Norm     1Fam     2Story            6            5       1999
# 1456       Norm     1Fam     1Story            6            6       1978
# 1457       Norm     1Fam     2Story            7            9       1941
# 1458       Norm     1Fam     1Story            5            6       1950
# 1459       Norm     1Fam     1Story            5            6       1965
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0             2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1             1976     Gable  CompShg     MetalSd     MetalSd       None
# 2             2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 3             1970     Gable  CompShg     Wd Sdng     Wd Shng       None
# 4             2000     Gable  CompShg     VinylSd     VinylSd    BrkFace
# ...            ...       ...      ...         ...         ...        ...
# 1455          2000     Gable  CompShg     VinylSd     VinylSd       None
# 1456          1988     Gable  CompShg     Plywood     Plywood      Stone
# 1457          2006     Gable  CompShg     CemntBd     CmentBd       None
# 1458          1996       Hip  CompShg     MetalSd     MetalSd       None
# 1459          1965     Gable  CompShg     HdBoard     HdBoard       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# 0          196.0        Gd        TA      PConc       Gd       TA
# 1            0.0        TA        TA     CBlock       Gd       TA
# 2          162.0        Gd        TA      PConc       Gd       TA
# 3            0.0        TA        TA     BrkTil       TA       Gd
# 4          350.0        Gd        TA      PConc       Gd       TA
# ...          ...       ...       ...        ...      ...      ...
# 1455         0.0        TA        TA      PConc       Gd       TA
# 1456       119.0        TA        TA     CBlock       Gd       TA
# 1457         0.0        Ex        Gd      Stone       TA       Gd
# 1458         0.0        TA        TA     CBlock       TA       TA
# 1459         0.0        Gd        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# 0              No          GLQ         706          Unf           0
# 1              Gd          ALQ         978          Unf           0
# 2              Mn          GLQ         486          Unf           0
# 3              No          ALQ         216          Unf           0
# 4              Av          GLQ         655          Unf           0
# ...           ...          ...         ...          ...         ...
# 1455           No          Unf           0          Unf           0
# 1456           No          ALQ         790          Rec         163
# 1457           No          GLQ         275          Unf           0
# 1458           Mn          GLQ          49          Rec        1029
# 1459           No          BLQ         830          LwQ         290
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# 0           150          856    GasA        Ex          Y      SBrkr
# 1           284         1262    GasA        Ex          Y      SBrkr
# 2           434          920    GasA        Ex          Y      SBrkr
# 3           540          756    GasA        Gd          Y      SBrkr
# 4           490         1145    GasA        Ex          Y      SBrkr
# ...         ...          ...     ...       ...        ...        ...
# 1455        953          953    GasA        Ex          Y      SBrkr
# 1456        589         1542    GasA        TA          Y      SBrkr
# 1457        877         1152    GasA        Ex          Y      SBrkr
# 1458          0         1078    GasA        Gd          Y      FuseA
# 1459        136         1256    GasA        Gd          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0          856       854             0       1710             1             0
# 1         1262         0             0       1262             0             1
# 2          920       866             0       1786             1             0
# 3          961       756             0       1717             1             0
# 4         1145      1053             0       2198             1             0
# ...        ...       ...           ...        ...           ...           ...
# 1455       953       694             0       1647             0             0
# 1456      2073         0             0       2073             1             0
# 1457      1188      1152             0       2340             0             0
# 1458      1078         0             0       1078             1             0
# 1459      1256         0             0       1256             1             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# 0            2         1             3             1          Gd
# 1            2         0             3             1          TA
# 2            2         1             3             1          Gd
# 3            1         0             3             1          Gd
# 4            2         1             4             1          Gd
# ...        ...       ...           ...           ...         ...
# 1455         2         1             3             1          TA
# 1456         2         0             3             1          TA
# 1457         2         0             4             1          Gd
# 1458         1         0             2             1          Gd
# 1459         1         1             3             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# 0                8        Typ           0         NaN     Attchd       2003.0
# 1                6        Typ           1          TA     Attchd       1976.0
# 2                6        Typ           1          TA     Attchd       2001.0
# 3                7        Typ           1          Gd     Detchd       1998.0
# 4                9        Typ           1          TA     Attchd       2000.0
# ...            ...        ...         ...         ...        ...          ...
# 1455             7        Typ           1          TA     Attchd       1999.0
# 1456             7       Min1           2          TA     Attchd       1978.0
# 1457             9        Typ           2          Gd     Attchd       1941.0
# 1458             5        Typ           0         NaN     Attchd       1950.0
# 1459             6        Typ           0         NaN     Attchd       1965.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# 0             RFn           2         548         TA         TA          Y
# 1             RFn           2         460         TA         TA          Y
# 2             RFn           2         608         TA         TA          Y
# 3             Unf           3         642         TA         TA          Y
# 4             RFn           3         836         TA         TA          Y
# ...           ...         ...         ...        ...        ...        ...
# 1455          RFn           2         460         TA         TA          Y
# 1456          Unf           2         500         TA         TA          Y
# 1457          RFn           1         252         TA         TA          Y
# 1458          Unf           1         240         TA         TA          Y
# 1459          Fin           1         276         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# 0            0    NaN    NaN         NaN        0       2    2008       WD
# 1            0    NaN    NaN         NaN        0       5    2007       WD
# 2            0    NaN    NaN         NaN        0       9    2008       WD
# 3            0    NaN    NaN         NaN        0       2    2006       WD
# 4            0    NaN    NaN         NaN        0      12    2008       WD
# ...        ...    ...    ...         ...      ...     ...     ...      ...
# 1455         0    NaN    NaN         NaN        0       8    2007       WD
# 1456         0    NaN  MnPrv         NaN        0       2    2010       WD
# 1457         0    NaN  GdPrv        Shed     2500       5    2010       WD
# 1458         0    NaN    NaN         NaN        0       4    2010       WD
# 1459         0    NaN    NaN         NaN        0       6    2008       WD
#
#      SaleCondition  SalePrice  LotFrontagenan  MasVnrAreanan  GarageYrBltnan  \
# 0           Normal     208500               0              0               0
# 1           Normal     181500               0              0               0
# 2           Normal     223500               0              0               0
# 3          Abnorml     140000               0              0               0
# 4           Normal     250000               0              0               0
# ...            ...        ...             ...            ...             ...
# 1455        Normal     175000               0              0               0
# 1456        Normal     210000               0              0               0
# 1457        Normal     266500               0              0               0
# 1458        Normal     142125               0              0               0
# 1459        Normal     147500               0              0               0
#
#       GarageYrBltage of house  YearBuiltage of house  YearRemodAddage of house
# 0                         5.0                      5                         5
# 1                        31.0                     31                        31
# 2                         7.0                      7                         6
# 3                         8.0                     91                        36
# 4                         8.0                      8                         8
# ...                       ...                    ...                       ...
# 1455                      8.0                      8                         7
# 1456                     32.0                     32                        22
# 1457                     69.0                     69                         4
# 1458                     60.0                     60                        14
# 1459                     43.0                     43                        43
#
# [1460 rows x 87 columns]
